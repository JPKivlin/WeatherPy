# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Starting Data Retrieval     ")
print("-----------------------------")


record_count = 1
set_count = 1
# Out:
# Starting Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Weather": city_description,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | kangaba
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | husavik
# Processing Record 6 of Set 1 | abu dhabi
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | bandarbeyla
# Processing Record 9 of Set 1 | cantagallo
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | keuruu
# Processing Record 12 of Set 1 | bjornevatn
# Processing Record 13 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | den helder
# Processing Record 17 of Set 1 | kidal
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | clarence town
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | ginir
# Processing Record 23 of Set 1 | viedma
# Processing Record 24 of Set 1 | oranjemund
# Processing Record 25 of Set 1 | salalah
# Processing Record 26 of Set 1 | carbonia
# Processing Record 27 of Set 1 | bereda
# Processing Record 28 of Set 1 | kerouane
# Processing Record 29 of Set 1 | ilulissat
# Processing Record 30 of Set 1 | dudinka
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | novyye burasy
# Processing Record 33 of Set 1 | gazojak
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | rybachiy
# Processing Record 36 of Set 1 | oreanda
# City not found. Skipping...
# Processing Record 37 of Set 1 | gandorhun
# Processing Record 38 of Set 1 | zhezkazgan
# Processing Record 39 of Set 1 | nanortalik
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | axim
# Processing Record 42 of Set 1 | pisco
# Processing Record 43 of Set 1 | sambava
# Processing Record 44 of Set 1 | brae
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | nyirbogdany
# Processing Record 48 of Set 1 | batelov
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | stayner
# Processing Record 1 of Set 2 | moose factory
# Processing Record 2 of Set 2 | tsiroanomandidy
# Processing Record 3 of Set 2 | tavda
# Processing Record 4 of Set 2 | pangnirtung
# Processing Record 5 of Set 2 | lyngseidet
# Processing Record 6 of Set 2 | longyearbyen
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | corrente
# Processing Record 9 of Set 2 | dawlatabad
# Processing Record 10 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | quelimane
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | kikwit
# Processing Record 16 of Set 2 | tessalit
# Processing Record 17 of Set 2 | hammerfest
# Processing Record 18 of Set 2 | klaksvik
# Processing Record 19 of Set 2 | watsa
# Processing Record 20 of Set 2 | ilam
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | herat
# Processing Record 24 of Set 2 | riachao das neves
# Processing Record 25 of Set 2 | akhtubinsk
# Processing Record 26 of Set 2 | severnyy
# Processing Record 27 of Set 2 | necochea
# Processing Record 28 of Set 2 | hamilton
# Processing Record 29 of Set 2 | pokhara
# Processing Record 30 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 2 | ayagoz
# Processing Record 32 of Set 2 | moba
# Processing Record 33 of Set 2 | laguna
# Processing Record 34 of Set 2 | cockburn town
# Processing Record 35 of Set 2 | mahanoro
# Processing Record 36 of Set 2 | sao filipe
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | belyy yar
# Processing Record 39 of Set 2 | rawson
# Processing Record 40 of Set 2 | dingle
# Processing Record 41 of Set 2 | los llanos de aridane
# Processing Record 42 of Set 2 | iqaluit
# Processing Record 43 of Set 2 | carmo
# Processing Record 44 of Set 2 | robertsport
# Processing Record 45 of Set 2 | luanda
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | mecca
# Processing Record 48 of Set 2 | porto novo
# Processing Record 49 of Set 2 | saldanha
# Processing Record 50 of Set 2 | cidreira
# Processing Record 1 of Set 3 | inta
# Processing Record 2 of Set 3 | harwich
# Processing Record 3 of Set 3 | milin
# Processing Record 4 of Set 3 | zhitikara
# City not found. Skipping...
# Processing Record 5 of Set 3 | barhi
# Processing Record 6 of Set 3 | hualmay
# Processing Record 7 of Set 3 | sakakah
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | general roca
# Processing Record 10 of Set 3 | chuy
# Processing Record 11 of Set 3 | san pedro de ycuamandiyu
# Processing Record 12 of Set 3 | verkhnyaya inta
# Processing Record 13 of Set 3 | ilava
# Processing Record 14 of Set 3 | sesheke
# Processing Record 15 of Set 3 | jilib
# Processing Record 16 of Set 3 | crotone
# Processing Record 17 of Set 3 | piacabucu
# Processing Record 18 of Set 3 | namikupa
# Processing Record 19 of Set 3 | tocopilla
# Processing Record 20 of Set 3 | santa marta
# Processing Record 21 of Set 3 | sisimiut
# Processing Record 22 of Set 3 | vestmannaeyjar
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | la palma
# Processing Record 25 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 3 | cruden bay
# City not found. Skipping...
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | praia da vitoria
# Processing Record 30 of Set 3 | kibaya
# Processing Record 31 of Set 3 | torbay
# Processing Record 32 of Set 3 | saint-augustin
# Processing Record 33 of Set 3 | torres
# Processing Record 34 of Set 3 | taltal
# Processing Record 35 of Set 3 | redcar
# Processing Record 36 of Set 3 | bhainsdehi
# Processing Record 37 of Set 3 | qaqortoq
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | inhambane
# Processing Record 40 of Set 3 | am timan
# Processing Record 41 of Set 3 | marsh harbour
# Processing Record 42 of Set 3 | hambantota
# Processing Record 43 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 3 | jijiga
# Processing Record 45 of Set 3 | trairi
# Processing Record 46 of Set 3 | lagoa
# Processing Record 47 of Set 3 | aksehir
# Processing Record 48 of Set 3 | karlstad
# Processing Record 49 of Set 3 | nizhniy odes
# Processing Record 50 of Set 3 | richards bay
# Processing Record 1 of Set 4 | hobyo
# Processing Record 2 of Set 4 | hauterive
# Processing Record 3 of Set 4 | doka
# Processing Record 4 of Set 4 | znamenskoye
# Processing Record 5 of Set 4 | caravelas
# Processing Record 6 of Set 4 | la plata
# Processing Record 7 of Set 4 | vila velha
# Processing Record 8 of Set 4 | catio
# Processing Record 9 of Set 4 | uige
# Processing Record 10 of Set 4 | concepcion del uruguay
# Processing Record 11 of Set 4 | xudat
# Processing Record 12 of Set 4 | tasgaon
# Processing Record 13 of Set 4 | elizabeth city
# Processing Record 14 of Set 4 | omboue
# Processing Record 15 of Set 4 | lerwick
# Processing Record 16 of Set 4 | sarany
# Processing Record 17 of Set 4 | sompeta
# Processing Record 18 of Set 4 | sarankhola
# Processing Record 19 of Set 4 | aquiraz
# Processing Record 20 of Set 4 | morropon
# Processing Record 21 of Set 4 | balkanabat
# Processing Record 22 of Set 4 | jizan
# Processing Record 23 of Set 4 | oussouye
# Processing Record 24 of Set 4 | saint-cyr-sur-loire
# Processing Record 25 of Set 4 | vuktyl
# Processing Record 26 of Set 4 | kruisfontein
# Processing Record 27 of Set 4 | oktyabrskoye
# Processing Record 28 of Set 4 | aktash
# Processing Record 29 of Set 4 | komsomolskoye
# Processing Record 30 of Set 4 | ponta delgada
# Processing Record 31 of Set 4 | makaryev
# Processing Record 32 of Set 4 | yambio
# Processing Record 33 of Set 4 | paamiut
# Processing Record 34 of Set 4 | spiridonovka
# Processing Record 35 of Set 4 | bonavista
# Processing Record 36 of Set 4 | rincon
# Processing Record 37 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 38 of Set 4 | calvinia
# Processing Record 39 of Set 4 | dalbandin
# Processing Record 40 of Set 4 | georgiyevka
# Processing Record 41 of Set 4 | najran
# Processing Record 42 of Set 4 | jalu
# Processing Record 43 of Set 4 | muros
# Processing Record 44 of Set 4 | bjerkvik
# Processing Record 45 of Set 4 | rafai
# Processing Record 46 of Set 4 | miraflores
# Processing Record 47 of Set 4 | hofn
# Processing Record 48 of Set 4 | auburn
# Processing Record 49 of Set 4 | tonantins
# Processing Record 50 of Set 4 | ust-kulom
# Processing Record 1 of Set 5 | granadilla de abona
# Processing Record 2 of Set 5 | saint-pierre
# Processing Record 3 of Set 5 | agirish
# Processing Record 4 of Set 5 | souillac
# Processing Record 5 of Set 5 | sept-iles
# Processing Record 6 of Set 5 | touros
# Processing Record 7 of Set 5 | yabassi
# Processing Record 8 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 5 | bambous virieux
# Processing Record 10 of Set 5 | porto belo
# Processing Record 11 of Set 5 | camacha
# Processing Record 12 of Set 5 | manono
# Processing Record 13 of Set 5 | salinopolis
# Processing Record 14 of Set 5 | camacupa
# Processing Record 15 of Set 5 | khelyulya
# Processing Record 16 of Set 5 | kotka
# Processing Record 17 of Set 5 | puertollano
# Processing Record 18 of Set 5 | sokoni
# Processing Record 19 of Set 5 | zarichne
# Processing Record 20 of Set 5 | megion
# Processing Record 21 of Set 5 | aden
# Processing Record 22 of Set 5 | minab
# Processing Record 23 of Set 5 | ucar
# Processing Record 24 of Set 5 | henties bay
# Processing Record 25 of Set 5 | nikolskiy
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | slovenj gradec
# Processing Record 28 of Set 5 | kashi
# Processing Record 29 of Set 5 | codrington
# Processing Record 30 of Set 5 | cavan
# Processing Record 31 of Set 5 | colares
# Processing Record 32 of Set 5 | aksu
# Processing Record 33 of Set 5 | wattegama
# Processing Record 34 of Set 5 | gavrilov-yam
# Processing Record 35 of Set 5 | oriximina
# Processing Record 36 of Set 5 | uyovu
# Processing Record 37 of Set 5 | takoradi
# Processing Record 38 of Set 5 | lahij
# Processing Record 39 of Set 5 | roald
# Processing Record 40 of Set 5 | tatarsk
# Processing Record 41 of Set 5 | stamford
# Processing Record 42 of Set 5 | bilma
# Processing Record 43 of Set 5 | ati
# Processing Record 44 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 5 | saint-georges
# Processing Record 46 of Set 5 | atlantic beach
# Processing Record 47 of Set 5 | maceio
# Processing Record 48 of Set 5 | lyngdal
# Processing Record 49 of Set 5 | coquimbo
# Processing Record 50 of Set 5 | port elgin
# Processing Record 1 of Set 6 | umea
# Processing Record 2 of Set 6 | krasnoselkup
# Processing Record 3 of Set 6 | san miguel
# Processing Record 4 of Set 6 | kushalgarh
# Processing Record 5 of Set 6 | santa cruz
# Processing Record 6 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 6 | salvador
# Processing Record 8 of Set 6 | shache
# Processing Record 9 of Set 6 | nicolas bravo
# Processing Record 10 of Set 6 | van wert
# Processing Record 11 of Set 6 | aksarka
# Processing Record 12 of Set 6 | asfi
# Processing Record 13 of Set 6 | taybad
# Processing Record 14 of Set 6 | ancud
# Processing Record 15 of Set 6 | jagtial
# Processing Record 16 of Set 6 | aripuana
# Processing Record 17 of Set 6 | uyuni
# Processing Record 18 of Set 6 | rorvik
# Processing Record 19 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 20 of Set 6 | veinticinco de mayo
# Processing Record 21 of Set 6 | olinda
# Processing Record 22 of Set 6 | cururupu
# Processing Record 23 of Set 6 | luderitz
# Processing Record 24 of Set 6 | cabinda
# Processing Record 25 of Set 6 | port-de-paix
# City not found. Skipping...
# Processing Record 26 of Set 6 | malinovoye ozero
# Processing Record 27 of Set 6 | adiake
# Processing Record 28 of Set 6 | babugarh
# Processing Record 29 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 30 of Set 6 | kutum
# Processing Record 31 of Set 6 | les cayes
# Processing Record 32 of Set 6 | kirishi
# Processing Record 33 of Set 6 | san juan
# Processing Record 34 of Set 6 | antofagasta
# Processing Record 35 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 6 | saint anthony
# Processing Record 37 of Set 6 | jutai
# Processing Record 38 of Set 6 | birin
# Processing Record 39 of Set 6 | puri
# Processing Record 40 of Set 6 | grindavik
# Processing Record 41 of Set 6 | manicore
# Processing Record 42 of Set 6 | cobh
# Processing Record 43 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 44 of Set 6 | libreville
# Processing Record 45 of Set 6 | utrecht
# Processing Record 46 of Set 6 | carahue
# Processing Record 47 of Set 6 | rudbar
# Processing Record 48 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 49 of Set 6 | almeirim
# Processing Record 50 of Set 6 | melekhovskaya
# City not found. Skipping...
# Processing Record 1 of Set 7 | arkhangelsk
# Processing Record 2 of Set 7 | jarocin
# Processing Record 3 of Set 7 | coulihaut
# City not found. Skipping...
# Processing Record 4 of Set 7 | kousseri
# Processing Record 5 of Set 7 | matsanga
# City not found. Skipping...
# Processing Record 6 of Set 7 | togur
# Processing Record 7 of Set 7 | putina
# Processing Record 8 of Set 7 | coari
# Processing Record 9 of Set 7 | goderich
# Processing Record 10 of Set 7 | turtkul
# City not found. Skipping...
# Processing Record 11 of Set 7 | lethem
# Processing Record 12 of Set 7 | kabo
# Processing Record 13 of Set 7 | saint-martin-boulogne
# Processing Record 14 of Set 7 | gourcy
# Processing Record 15 of Set 7 | arona
# Processing Record 16 of Set 7 | seydi
# Processing Record 17 of Set 7 | pitimbu
# Processing Record 18 of Set 7 | itaituba
# Processing Record 19 of Set 7 | belmonte
# Processing Record 20 of Set 7 | vardo
# Processing Record 21 of Set 7 | harper
# Processing Record 22 of Set 7 | amapa
# Processing Record 23 of Set 7 | nainpur
# Processing Record 24 of Set 7 | jiroft
# City not found. Skipping...
# Processing Record 25 of Set 7 | gumushane
# City not found. Skipping...
# Processing Record 26 of Set 7 | talas
# Processing Record 27 of Set 7 | kalmunai
# Processing Record 28 of Set 7 | floriano
# Processing Record 29 of Set 7 | viseu
# Processing Record 30 of Set 7 | san francisco
# Processing Record 31 of Set 7 | vozhega
# Processing Record 32 of Set 7 | guarapari
# Processing Record 33 of Set 7 | bubaque
# Processing Record 34 of Set 7 | nioro
# Processing Record 35 of Set 7 | dossor
# Processing Record 36 of Set 7 | novomoskovsk
# Processing Record 37 of Set 7 | riyadh
# Processing Record 38 of Set 7 | chitral
# Processing Record 39 of Set 7 | maykor
# Processing Record 40 of Set 7 | skelleftea
# Processing Record 41 of Set 7 | bogande
# Processing Record 42 of Set 7 | kariba
# Processing Record 43 of Set 7 | marquette
# Processing Record 44 of Set 7 | volchansk
# Processing Record 45 of Set 7 | mishkino
# Processing Record 46 of Set 7 | olafsvik
# Processing Record 47 of Set 7 | palmares do sul
# Processing Record 48 of Set 7 | banyo
# Processing Record 49 of Set 7 | san miguel de cauri
# Processing Record 50 of Set 7 | jumla
# Processing Record 1 of Set 8 | walvis bay
# Processing Record 2 of Set 8 | tazmalt
# Processing Record 3 of Set 8 | yabrud
# Processing Record 4 of Set 8 | sayville
# Processing Record 5 of Set 8 | fasa
# Processing Record 6 of Set 8 | havre-saint-pierre
# Processing Record 7 of Set 8 | le port
# Processing Record 8 of Set 8 | gat
# Processing Record 9 of Set 8 | faya
# Processing Record 10 of Set 8 | mehamn
# Processing Record 11 of Set 8 | afanasyevo
# City not found. Skipping...
# Processing Record 12 of Set 8 | shu
# Processing Record 13 of Set 8 | sao felix do xingu
# Processing Record 14 of Set 8 | simnas
# Processing Record 15 of Set 8 | coxim
# Processing Record 16 of Set 8 | tanout
# Processing Record 17 of Set 8 | mubi
# Processing Record 18 of Set 8 | sika
# Processing Record 19 of Set 8 | derzhavinsk
# Processing Record 20 of Set 8 | mbala
# Processing Record 21 of Set 8 | velykyy burluk
# Processing Record 22 of Set 8 | harlingen
# Processing Record 23 of Set 8 | phalombe
# Processing Record 24 of Set 8 | mpika
# Processing Record 25 of Set 8 | morros
# Processing Record 26 of Set 8 | florida
# Processing Record 27 of Set 8 | uaua
# Processing Record 28 of Set 8 | plouzane
# Processing Record 29 of Set 8 | weston
# Processing Record 30 of Set 8 | tambura
# Processing Record 31 of Set 8 | sabaudia
# Processing Record 32 of Set 8 | miragoane
# Processing Record 33 of Set 8 | hof
# Processing Record 34 of Set 8 | pudozh
# Processing Record 35 of Set 8 | marsa matruh
# Processing Record 36 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 37 of Set 8 | cayenne
# Processing Record 38 of Set 8 | lagos
# Processing Record 39 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 8 | the valley
# Processing Record 41 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 8 | ostrovnoy
# Processing Record 43 of Set 8 | rocha
# Processing Record 44 of Set 8 | talnakh
# Processing Record 45 of Set 8 | arlit
# Processing Record 46 of Set 8 | mansa
# Processing Record 47 of Set 8 | sudova vyshnya
# Processing Record 48 of Set 8 | les escoumins
# Processing Record 49 of Set 8 | velikie luki
# City not found. Skipping...
# Processing Record 50 of Set 8 | vytegra
# Processing Record 1 of Set 9 | distraccion
# Processing Record 2 of Set 9 | beloha
# Processing Record 3 of Set 9 | sabha
# Processing Record 4 of Set 9 | bathsheba
# Processing Record 5 of Set 9 | matay
# Processing Record 6 of Set 9 | itarema
# Processing Record 7 of Set 9 | yining
# Processing Record 8 of Set 9 | columbus
# Processing Record 9 of Set 9 | lubango
# Processing Record 10 of Set 9 | borisoglebskiy
# Processing Record 11 of Set 9 | atar
# Processing Record 12 of Set 9 | barsovo
# Processing Record 13 of Set 9 | porto torres
# Processing Record 14 of Set 9 | peniche
# Processing Record 15 of Set 9 | gurupi
# Processing Record 16 of Set 9 | chicama
# Processing Record 17 of Set 9 | port-gentil
# Processing Record 18 of Set 9 | san carlos
# Processing Record 19 of Set 9 | jacmel
# Processing Record 20 of Set 9 | santa maria
# Processing Record 21 of Set 9 | nizhnedevitsk
# Processing Record 22 of Set 9 | jacareacanga
# Processing Record 23 of Set 9 | bonthe
# Processing Record 24 of Set 9 | gravdal
# Processing Record 25 of Set 9 | energetik
# Processing Record 26 of Set 9 | fulacunda
# City not found. Skipping...
# Processing Record 27 of Set 9 | komsomolskiy
# Processing Record 28 of Set 9 | lodwar
# Processing Record 29 of Set 9 | bagotville
# Processing Record 30 of Set 9 | geraldton
# Processing Record 31 of Set 9 | zambezi
# Processing Record 32 of Set 9 | vicuna
# Processing Record 33 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 9 | gidole
# Processing Record 35 of Set 9 | nadapuram
# Processing Record 36 of Set 9 | haysyn
# Processing Record 37 of Set 9 | anzio
# Processing Record 38 of Set 9 | san cristobal
# Processing Record 39 of Set 9 | clyde river
# Processing Record 40 of Set 9 | umm lajj
# Processing Record 41 of Set 9 | chaman
# Processing Record 42 of Set 9 | raga
# Processing Record 43 of Set 9 | mikhaylovka
# Processing Record 44 of Set 9 | saint-francois
# Processing Record 45 of Set 9 | changji
# Processing Record 46 of Set 9 | nsoko
# Processing Record 47 of Set 9 | melo
# Processing Record 48 of Set 9 | bengkulu
# Processing Record 49 of Set 9 | abhar
# Processing Record 50 of Set 9 | uglovka
# Processing Record 1 of Set 10 | boa vista
# Processing Record 2 of Set 10 | urumqi
# Processing Record 3 of Set 10 | synya
# Processing Record 4 of Set 10 | opuwo
# Processing Record 5 of Set 10 | pagegiai
# Processing Record 6 of Set 10 | lohardaga
# Processing Record 7 of Set 10 | salamanca
# Processing Record 8 of Set 10 | bougouni
# Processing Record 9 of Set 10 | maiduguri
# Processing Record 10 of Set 10 | temyasovo
# Processing Record 11 of Set 10 | guacui
# Processing Record 12 of Set 10 | anjozorobe
# Processing Record 13 of Set 10 | tsentralnyy
# City not found. Skipping...
# Processing Record 14 of Set 10 | shahrud
# Processing Record 15 of Set 10 | barra do garcas
# Processing Record 16 of Set 10 | kedrovyy
# Processing Record 17 of Set 10 | vestmanna
# Processing Record 18 of Set 10 | syamzha
# Processing Record 19 of Set 10 | formosa
# Processing Record 20 of Set 10 | glazov
# Processing Record 21 of Set 10 | inirida
# Processing Record 22 of Set 10 | rio gallegos
# Processing Record 23 of Set 10 | abha
# Processing Record 24 of Set 10 | mashhad
# Processing Record 25 of Set 10 | camana
# Processing Record 26 of Set 10 | krumovgrad
# Processing Record 27 of Set 10 | mossendjo
# Processing Record 28 of Set 10 | otradnyy
# Processing Record 29 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 30 of Set 10 | cumra
# Processing Record 31 of Set 10 | azul
# Processing Record 32 of Set 10 | izhma
# Processing Record 33 of Set 10 | novodugino
# Processing Record 34 of Set 10 | sao joao da barra
# Processing Record 35 of Set 10 | coswig
# Processing Record 36 of Set 10 | nsanje
# Processing Record 37 of Set 10 | kharp
# Processing Record 38 of Set 10 | manoharpur
# Processing Record 39 of Set 10 | miandrivazo
# Processing Record 40 of Set 10 | las tunas
# Processing Record 41 of Set 10 | albacete
# Processing Record 42 of Set 10 | camopi
# Processing Record 43 of Set 10 | korla
# Processing Record 44 of Set 10 | karasjok
# Processing Record 45 of Set 10 | bandundu
# Processing Record 46 of Set 10 | hvide sande
# Processing Record 47 of Set 10 | skegness
# Processing Record 48 of Set 10 | nantucket
# Processing Record 49 of Set 10 | thinadhoo
# Processing Record 50 of Set 10 | zabid
# Processing Record 1 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 11 | greenville
# Processing Record 3 of Set 11 | inyonga
# Processing Record 4 of Set 11 | gamba
# Processing Record 5 of Set 11 | yar-sale
# Processing Record 6 of Set 11 | stolbovaya
# Processing Record 7 of Set 11 | altoona
# Processing Record 8 of Set 11 | nadym
# Processing Record 9 of Set 11 | tucuma
# Processing Record 10 of Set 11 | sefophe
# Processing Record 11 of Set 11 | goure
# Processing Record 12 of Set 11 | krasnoye
# Processing Record 13 of Set 11 | strezhevoy
# Processing Record 14 of Set 11 | goundam
# Processing Record 15 of Set 11 | vila franca do campo
# Processing Record 16 of Set 11 | cuamba
# Processing Record 17 of Set 11 | biscarrosse
# Processing Record 18 of Set 11 | ondangwa
# Processing Record 19 of Set 11 | chapais
# Processing Record 20 of Set 11 | waldoboro
# Processing Record 21 of Set 11 | tawzar
# City not found. Skipping...
# Processing Record 22 of Set 11 | kolokani
# Processing Record 23 of Set 11 | elat
# Processing Record 24 of Set 11 | knysna
# Processing Record 25 of Set 11 | banda aceh
# Processing Record 26 of Set 11 | bahia blanca
# Processing Record 27 of Set 11 | san ramon de la nueva oran
# Processing Record 28 of Set 11 | baherden
# Processing Record 29 of Set 11 | la asuncion
# Processing Record 30 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 11 | alta floresta
# Processing Record 32 of Set 11 | parambu
# Processing Record 33 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 34 of Set 11 | tsumeb
# Processing Record 35 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 11 | sechura
# Processing Record 37 of Set 11 | kifri
# Processing Record 38 of Set 11 | goma
# Processing Record 39 of Set 11 | rivera
# Processing Record 40 of Set 11 | ilhabela
# Processing Record 41 of Set 11 | crailsheim
# Processing Record 42 of Set 11 | kontagora
# Processing Record 43 of Set 11 | eyl
# Processing Record 44 of Set 11 | luau
# Processing Record 45 of Set 11 | porto nacional
# Processing Record 46 of Set 11 | kovdor
# Processing Record 47 of Set 11 | uvarovka
# Processing Record 48 of Set 11 | san andres
# Processing Record 49 of Set 11 | trelew
# Processing Record 50 of Set 11 | pangody
# Processing Record 1 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 12 | wum
# Processing Record 3 of Set 12 | uvinza
# Processing Record 4 of Set 12 | manyana
# Processing Record 5 of Set 12 | lasa
# Processing Record 6 of Set 12 | pascagoula
# Processing Record 7 of Set 12 | porto walter
# Processing Record 8 of Set 12 | westport
# Processing Record 9 of Set 12 | vilhena
# Processing Record 10 of Set 12 | khalkhal
# Processing Record 11 of Set 12 | sao raimundo das mangabeiras
# Processing Record 12 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 13 of Set 12 | yavatmal
# Processing Record 14 of Set 12 | huarmey
# Processing Record 15 of Set 12 | lesogorskiy
# Processing Record 16 of Set 12 | lerik
# Processing Record 17 of Set 12 | cabrera
# Processing Record 18 of Set 12 | pedasi
# Processing Record 19 of Set 12 | arthur
# Processing Record 20 of Set 12 | lusambo
# Processing Record 21 of Set 12 | saint-joseph
# Processing Record 22 of Set 12 | chililabombwe
# Processing Record 23 of Set 12 | chervonohryhorivka
# Processing Record 24 of Set 12 | ewo
# Processing Record 25 of Set 12 | marand
# Processing Record 26 of Set 12 | presidencia roque saenz pena
# Processing Record 27 of Set 12 | carbondale
# Processing Record 28 of Set 12 | cap malheureux
# Processing Record 29 of Set 12 | ust-tsilma
# Processing Record 30 of Set 12 | quatre cocos
# Processing Record 31 of Set 12 | riberalta
# Processing Record 32 of Set 12 | maturin
# Processing Record 33 of Set 12 | piploda
# Processing Record 34 of Set 12 | mayumba
# Processing Record 35 of Set 12 | ongandjera
# Processing Record 36 of Set 12 | kampene
# Processing Record 37 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 38 of Set 12 | shieli
# Processing Record 39 of Set 12 | bom jesus
# Processing Record 40 of Set 12 | offa
# Processing Record 41 of Set 12 | nata
# Processing Record 42 of Set 12 | adrar
# Processing Record 43 of Set 12 | padang
# Processing Record 44 of Set 12 | shahreza
# Processing Record 45 of Set 12 | mozarlandia
# Processing Record 46 of Set 12 | nova gorica
# Processing Record 47 of Set 12 | dakoro
# Processing Record 48 of Set 12 | grazhdanskoye pervoye
# City not found. Skipping...
# Processing Record 49 of Set 12 | buraydah
# Processing Record 50 of Set 12 | weare
# Processing Record 1 of Set 13 | garner
# Processing Record 2 of Set 13 | beira
# Processing Record 3 of Set 13 | kudahuvadhoo
# Processing Record 4 of Set 13 | kadoma
# Processing Record 5 of Set 13 | castle bruce
# Processing Record 6 of Set 13 | skaelskor
# Processing Record 7 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 8 of Set 13 | odweyne
# Processing Record 9 of Set 13 | thompson
# Processing Record 10 of Set 13 | kang
# Processing Record 11 of Set 13 | bud
# Processing Record 12 of Set 13 | salekhard
# Processing Record 13 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 13 | kant
# Processing Record 15 of Set 13 | jalalabad
# Processing Record 16 of Set 13 | unai
# Processing Record 17 of Set 13 | proletarskiy
# Processing Record 18 of Set 13 | sovetskiy
# Processing Record 19 of Set 13 | sistranda
# Processing Record 20 of Set 13 | qurunbaliyah
# City not found. Skipping...
# Processing Record 21 of Set 13 | batsfjord
# Processing Record 22 of Set 13 | bardiyah
# Processing Record 23 of Set 13 | nicoya
# Processing Record 24 of Set 13 | isiro
# Processing Record 25 of Set 13 | kavaratti
# Processing Record 26 of Set 13 | eslov
# Processing Record 27 of Set 13 | yenagoa
# Processing Record 28 of Set 13 | yelanskiy
# Processing Record 29 of Set 13 | saint-louis
# Processing Record 30 of Set 13 | marsaxlokk
# Processing Record 31 of Set 13 | samana
# Processing Record 32 of Set 13 | kemijarvi
# Processing Record 33 of Set 13 | sanchez
# Processing Record 34 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 35 of Set 13 | dakar
# Processing Record 36 of Set 13 | ouadda
# Processing Record 37 of Set 13 | pavilosta
# Processing Record 38 of Set 13 | soldatskiy
# City not found. Skipping...
# Processing Record 39 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 13 | sorland
# Processing Record 41 of Set 13 | horta
# Processing Record 42 of Set 13 | filingue
# Processing Record 43 of Set 13 | sokolo
# Processing Record 44 of Set 13 | chinhoyi
# Processing Record 45 of Set 13 | rioja
# Processing Record 46 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 13 | leh
# Processing Record 48 of Set 13 | sfantu gheorghe
# Processing Record 49 of Set 13 | brigantine
# Processing Record 50 of Set 13 | luebo
# Processing Record 1 of Set 14 | port blair
# Processing Record 2 of Set 14 | joshimath
# Processing Record 3 of Set 14 | ostrov
# Processing Record 4 of Set 14 | lisakovsk
# Processing Record 5 of Set 14 | mmabatho
# Processing Record 6 of Set 14 | monrovia
# Processing Record 7 of Set 14 | aqtobe
# Processing Record 8 of Set 14 | monatele
# City not found. Skipping...
# Processing Record 9 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 10 of Set 14 | konstantinovskaya
# Processing Record 11 of Set 14 | abapo
# Processing Record 12 of Set 14 | kolobrzeg
# Processing Record 13 of Set 14 | namibe
# Processing Record 14 of Set 14 | schubelbach
# Processing Record 15 of Set 14 | yarmouth
# Processing Record 16 of Set 14 | mananjary
# Processing Record 17 of Set 14 | tursunzoda
# Processing Record 18 of Set 14 | abonnema
# Processing Record 19 of Set 14 | san pedro
# Processing Record 20 of Set 14 | hoshcha
# Processing Record 21 of Set 14 | ciudad bolivar
# Processing Record 22 of Set 14 | cabedelo
# Processing Record 23 of Set 14 | bondo
# Processing Record 24 of Set 14 | aswan
# Processing Record 25 of Set 14 | areia branca
# Processing Record 26 of Set 14 | pag
# Processing Record 27 of Set 14 | sangmelima
# Processing Record 28 of Set 14 | kamensk-uralskiy
# Processing Record 29 of Set 14 | hassleholm
# Processing Record 30 of Set 14 | muscat
# Processing Record 31 of Set 14 | mahabad
# Processing Record 32 of Set 14 | porto velho
# Processing Record 33 of Set 14 | comodoro rivadavia
# Processing Record 34 of Set 14 | la baule-escoublac
# Processing Record 35 of Set 14 | murdochville
# Processing Record 36 of Set 14 | shelburne
# Processing Record 37 of Set 14 | aasiaat
# Processing Record 38 of Set 14 | conde
# Processing Record 39 of Set 14 | yarkovo
# Processing Record 40 of Set 14 | abu kamal
# Processing Record 41 of Set 14 | pedernales
# Processing Record 42 of Set 14 | brora
# Processing Record 43 of Set 14 | maragogi
# Processing Record 44 of Set 14 | savannah bight
# Processing Record 45 of Set 14 | verdalsora
# City not found. Skipping...
# Processing Record 46 of Set 14 | yurla
# Processing Record 47 of Set 14 | berlevag
# Processing Record 48 of Set 14 | mizan teferi
# Processing Record 49 of Set 14 | zyryanskoye
# Processing Record 50 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 15 | marawi
# Processing Record 2 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 3 of Set 15 | mogadouro
# Processing Record 4 of Set 15 | nacala
# Processing Record 5 of Set 15 | kamenka
# Processing Record 6 of Set 15 | qobustan
# Processing Record 7 of Set 15 | estelle
# Processing Record 8 of Set 15 | micheweni
# Processing Record 9 of Set 15 | andenes
# Processing Record 10 of Set 15 | xai-xai
# Processing Record 11 of Set 15 | sinop
# Processing Record 12 of Set 15 | muisne
# Processing Record 13 of Set 15 | roura
# Processing Record 14 of Set 15 | mitsamiouli
# Processing Record 15 of Set 15 | puquio
# Processing Record 16 of Set 15 | durres
# Processing Record 17 of Set 15 | roma
# Processing Record 18 of Set 15 | mercedes
# Processing Record 19 of Set 15 | rajula
# Processing Record 20 of Set 15 | sangod
# Processing Record 21 of Set 15 | dodoma
# Processing Record 22 of Set 15 | murgab
# Processing Record 23 of Set 15 | nuuk
# Processing Record 24 of Set 15 | ayia galini
# Processing Record 25 of Set 15 | palafrugell
# Processing Record 26 of Set 15 | stornoway
# Processing Record 27 of Set 15 | valparaiso
# Processing Record 28 of Set 15 | bohicon
# Processing Record 29 of Set 15 | moi
# Processing Record 30 of Set 15 | rathdrum
# Processing Record 31 of Set 15 | thornbury
# Processing Record 32 of Set 15 | dietzenbach
# Processing Record 33 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 34 of Set 15 | portree
# Processing Record 35 of Set 15 | rio grande
# Processing Record 36 of Set 15 | safaga
# Processing Record 37 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 15 | chunian
# Processing Record 39 of Set 15 | yopal
# Processing Record 40 of Set 15 | azanka
# Processing Record 41 of Set 15 | salinas
# Processing Record 42 of Set 15 | autazes
# Processing Record 43 of Set 15 | zatoka
# Processing Record 44 of Set 15 | kargil
# Processing Record 45 of Set 15 | nautanwa
# Processing Record 46 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 47 of Set 15 | moskovskiy
# Processing Record 48 of Set 15 | tulu bolo
# Processing Record 49 of Set 15 | paragominas
# Processing Record 50 of Set 15 | bourg-en-bresse
# Processing Record 1 of Set 16 | ajdabiya
# Processing Record 2 of Set 16 | turayf
# Processing Record 3 of Set 16 | jadu
# Processing Record 4 of Set 16 | atasu
# Processing Record 5 of Set 16 | abalak
# Processing Record 6 of Set 16 | bahia honda
# Processing Record 7 of Set 16 | tiznit
# Processing Record 8 of Set 16 | loharu
# Processing Record 9 of Set 16 | pandharpur
# Processing Record 10 of Set 16 | turukhansk
# Processing Record 11 of Set 16 | kargasok
# Processing Record 12 of Set 16 | lyubytino
# Processing Record 13 of Set 16 | okakarara
# Processing Record 14 of Set 16 | ostersund
# Processing Record 15 of Set 16 | srisailam
# Processing Record 16 of Set 16 | saint austell
# Processing Record 17 of Set 16 | sur
# Processing Record 18 of Set 16 | katesh
# Processing Record 19 of Set 16 | igrim
# Processing Record 20 of Set 16 | nouakchott
# Processing Record 21 of Set 16 | carauari
# Processing Record 22 of Set 16 | cwmbran
# Processing Record 23 of Set 16 | tubruq
# City not found. Skipping...
# Processing Record 24 of Set 16 | kumla
# Processing Record 25 of Set 16 | lithakia
# Processing Record 26 of Set 16 | gilgit
# Processing Record 27 of Set 16 | chamba
# Processing Record 28 of Set 16 | formosa do rio preto
# Processing Record 29 of Set 16 | surt
# Processing Record 30 of Set 16 | clearwater
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather"]
city_data_df = city_data_df[new_order]
city_data_df.head(10)
# Out:
#             City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hithadhoo      MV  -0.6000  73.0833     81.95        70          99
# 1      Jamestown      US  42.0970 -79.2353     87.39        54          20
# 2        Kangaba      ML  11.9333  -8.4167     76.50        87          98
# 3  Mar Del Plata      AR -38.0023 -57.5575     48.22        61          40
# 4        Husavik      IS  66.0449 -17.3389     66.11        59          69
# 5      Abu Dhabi      AE  24.4667  54.3667    104.11        41           0
# 6        Ushuaia      AR -54.8000 -68.3000     49.66        53          20
# 7    Bandarbeyla      SO   9.4942  50.8122     75.76        86          33
# 8     Cantagallo      CO   7.3760 -73.9196     93.67        47           8
# 9      Cape Town      ZA -33.9258  18.4232     51.12        81           0
#
#    Wind Speed   Current Weather
# 0        5.88   overcast clouds
# 1        8.05        few clouds
# 2        3.38     moderate rain
# 3       14.97  scattered clouds
# 4        1.97     broken clouds
# 5        4.61         clear sky
# 6        6.91        few clouds
# 7       31.83  scattered clouds
# 8        2.48         clear sky
# 9        6.91         clear sky

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
